# %% [markdown]
# Praktikum: Toko dorayaki Doraemon

# %%
###Program ini dibuat untuk membatu Toko Dorayaki Doraemon menghitung ketubuhan awal dalam membuka toko di tokyo. Program ini menerima input berupa nama makanan, nama karakter, dan kata sifat untuk membuat nama toko. Selain itu, menghitung total dari Doraemon, Nobita , dan Shizuka, total pendapatan dari penjual doraykai, serta keuntungan yang di peroleh.

# %%
nama_makanan = "Dorayaki "
nama_karakter = "doraemon "
kata_sifat = "baik hati "
print(nama_makanan + nama_karakter + kata_sifat)
#pertama pertama masukkan variabel lalu lanjutnya menambahkan (=), setelah variabel gunakan tanda ("") dan print
# Out:
# Dorayaki doraemon baik hati

# %%
modal_Doraemon = 555000
modal_Nobita = 333000
modal_Shizuka = 222000
print(modal_Doraemon + modal_Nobita + modal_Shizuka)
#menghitung modal awal dan total modal = 1110000
#masukkan variabel modal, untuk harga tidak perlu menggukan tanda ("") lalu print dan jumlahkan semua modal
# Out:
# 1110000

# %%
jumlah_dorayaki = 350
harga_dorayaki = 5000
print(jumlah_dorayaki * harga_dorayaki)
#menghitung pendapatan Toko Dorayaki Doraemon = 1750000
#tuliskan variabel jumlah dan harga lalu print dan kalikan menggunakan tanda (*)
# Out:
# 1750000

# %%
modal_awal = 1110000
pendapatan_dorayaki = 1750000
print(pendapatan_dorayaki - modal_awal)
#menghitung keuntungan yang di dapat dari Toko Dorayaki Doraemon = 640000
#tuliskan variabel modal dan pendapatan lalu di print dan dikurangkan menggunakan tanda (-)
# Out:
# 640000

# %%
print("Keuntungan total adalah", "keuntungan")
#kesalahannya nobita adalah tidak menambahkan koma dan tanda petik
#tulikan print dan mmasukkan teks dan lihat apa yang salah
# Out:
# Keuntungan total adalah keuntungan
